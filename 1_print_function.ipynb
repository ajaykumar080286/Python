# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/Python/blob/main/1_print_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Wold")
# Out:
# Hello Wold

# %%
print(5)
# Out:
# 5

# %%
print(5.6)
# Out:
# 5.6

# %%
print(False)
# Out:
# False

# %%
print(True)
# Out:
# True

# %%
print("india" , "pakistan" , "america")
# Out:
# india pakistan america

# %%
print("india pakistan america")
# Out:
# india pakistan america

# %%
print("india", 5, True)
# Out:
# india 5 True

# %%
print()  #shift tab for document

# %%
print("india pakistan america")
# Out:
# india pakistan america

# %%
print("india" "pakistan" "america")
# Out:
# indiapakistanamerica

# %%
print("india", "pakistan", "america", sep="/")
# Out:
# india/pakistan/america

# %%
print("india", "pakistan", "america", sep="-")
# Out:
# india-pakistan-america

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end=' ')
print("World")
# Out:
# Hello World
