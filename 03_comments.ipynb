# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/Python/blob/main/03_comments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comment

# %%
#this is comment

# %%
#my name is ajay
#i am from Bihar
